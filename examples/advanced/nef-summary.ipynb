# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="637170724" href="javascript:toggle_input_637170724()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_637170724;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_637170724 = document.getElementById("637170724");
#                 var cell = link_637170724;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_637170724;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_637170724 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_637170724 = cell.previousElementSibling;
#                 }
#                 input_637170724.style.display = "none"; // hide
#
#                 toggle_input_637170724 = function() {
#                     if (input_637170724.style.display == "none") {
#                         input_637170724.style.display = ""; // show
#                         link_637170724.innerHTML = "Hide Input";
#                     } else {
#                         input_637170724.style.display = "none"; // hide
#                         link_637170724.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_637170724 = $("a[id='637170724']");
#                 var cell_637170724 = link_637170724.parents("div.cell:first");
#                 if (cell_637170724.length == 0) {
#                     cell_637170724 = link_637170724.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_637170724 = cell_637170724.children("div.input");
#                 if (input_637170724.length == 0) {
#                     input_637170724 = cell_637170724.prev("div.nbinput");
#                 }
#                 input_637170724.hide();
#
#                 toggle_input_637170724 = function() {
#                     if (input_637170724.is(':hidden')) {
#                         input_637170724.slideDown();
#                         link_637170724[0].innerHTML = "Hide Input";
#                     } else {
#                         input_637170724.slideUp();
#                         link_637170724[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="2115291448" href="javascript:toggle_input_2115291448()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2115291448;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2115291448 = document.getElementById("2115291448");
#                 var cell = link_2115291448;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2115291448;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2115291448 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2115291448 = cell.previousElementSibling;
#                 }
#                 input_2115291448.style.display = "none"; // hide
#
#                 toggle_input_2115291448 = function() {
#                     if (input_2115291448.style.display == "none") {
#                         input_2115291448.style.display = ""; // show
#                         link_2115291448.innerHTML = "Hide Input";
#                     } else {
#                         input_2115291448.style.display = "none"; // hide
#                         link_2115291448.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2115291448 = $("a[id='2115291448']");
#                 var cell_2115291448 = link_2115291448.parents("div.cell:first");
#                 if (cell_2115291448.length == 0) {
#                     cell_2115291448 = link_2115291448.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2115291448 = cell_2115291448.children("div.input");
#                 if (input_2115291448.length == 0) {
#                     input_2115291448 = cell_2115291448.prev("div.nbinput");
#                 }
#                 input_2115291448.hide();
#
#                 toggle_input_2115291448 = function() {
#                     if (input_2115291448.is(':hidden')) {
#                         input_2115291448.slideDown();
#                         link_2115291448[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2115291448.slideUp();
#                         link_2115291448[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="1748587707" href="javascript:toggle_input_1748587707()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1748587707;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1748587707 = document.getElementById("1748587707");
#                 var cell = link_1748587707;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1748587707;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1748587707 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1748587707 = cell.previousElementSibling;
#                 }
#                 input_1748587707.style.display = "none"; // hide
#
#                 toggle_input_1748587707 = function() {
#                     if (input_1748587707.style.display == "none") {
#                         input_1748587707.style.display = ""; // show
#                         link_1748587707.innerHTML = "Hide Input";
#                     } else {
#                         input_1748587707.style.display = "none"; // hide
#                         link_1748587707.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1748587707 = $("a[id='1748587707']");
#                 var cell_1748587707 = link_1748587707.parents("div.cell:first");
#                 if (cell_1748587707.length == 0) {
#                     cell_1748587707 = link_1748587707.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1748587707 = cell_1748587707.children("div.input");
#                 if (input_1748587707.length == 0) {
#                     input_1748587707 = cell_1748587707.prev("div.nbinput");
#                 }
#                 input_1748587707.hide();
#
#                 toggle_input_1748587707 = function() {
#                     if (input_1748587707.is(':hidden')) {
#                         input_1748587707.slideDown();
#                         link_1748587707[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1748587707.slideUp();
#                         link_1748587707[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="56639445" href="javascript:toggle_input_56639445()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_56639445;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_56639445 = document.getElementById("56639445");
#                 var cell = link_56639445;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_56639445;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_56639445 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_56639445 = cell.previousElementSibling;
#                 }
#                 input_56639445.style.display = "none"; // hide
#
#                 toggle_input_56639445 = function() {
#                     if (input_56639445.style.display == "none") {
#                         input_56639445.style.display = ""; // show
#                         link_56639445.innerHTML = "Hide Input";
#                     } else {
#                         input_56639445.style.display = "none"; // hide
#                         link_56639445.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_56639445 = $("a[id='56639445']");
#                 var cell_56639445 = link_56639445.parents("div.cell:first");
#                 if (cell_56639445.length == 0) {
#                     cell_56639445 = link_56639445.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_56639445 = cell_56639445.children("div.input");
#                 if (input_56639445.length == 0) {
#                     input_56639445 = cell_56639445.prev("div.nbinput");
#                 }
#                 input_56639445.hide();
#
#                 toggle_input_56639445 = function() {
#                     if (input_56639445.is(':hidden')) {
#                         input_56639445.slideDown();
#                         link_56639445[0].innerHTML = "Hide Input";
#                     } else {
#                         input_56639445.slideUp();
#                         link_56639445[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="1289299424" href="javascript:toggle_input_1289299424()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1289299424;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1289299424 = document.getElementById("1289299424");
#                 var cell = link_1289299424;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1289299424;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1289299424 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1289299424 = cell.previousElementSibling;
#                 }
#                 input_1289299424.style.display = "none"; // hide
#
#                 toggle_input_1289299424 = function() {
#                     if (input_1289299424.style.display == "none") {
#                         input_1289299424.style.display = ""; // show
#                         link_1289299424.innerHTML = "Hide Input";
#                     } else {
#                         input_1289299424.style.display = "none"; // hide
#                         link_1289299424.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1289299424 = $("a[id='1289299424']");
#                 var cell_1289299424 = link_1289299424.parents("div.cell:first");
#                 if (cell_1289299424.length == 0) {
#                     cell_1289299424 = link_1289299424.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1289299424 = cell_1289299424.children("div.input");
#                 if (input_1289299424.length == 0) {
#                     input_1289299424 = cell_1289299424.prev("div.nbinput");
#                 }
#                 input_1289299424.hide();
#
#                 toggle_input_1289299424 = function() {
#                     if (input_1289299424.is(':hidden')) {
#                         input_1289299424.slideDown();
#                         link_1289299424[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1289299424.slideUp();
#                         link_1289299424[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="892092261" href="javascript:toggle_input_892092261()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_892092261;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_892092261 = document.getElementById("892092261");
#                 var cell = link_892092261;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_892092261;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_892092261 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_892092261 = cell.previousElementSibling;
#                 }
#                 input_892092261.style.display = "none"; // hide
#
#                 toggle_input_892092261 = function() {
#                     if (input_892092261.style.display == "none") {
#                         input_892092261.style.display = ""; // show
#                         link_892092261.innerHTML = "Hide Input";
#                     } else {
#                         input_892092261.style.display = "none"; // hide
#                         link_892092261.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_892092261 = $("a[id='892092261']");
#                 var cell_892092261 = link_892092261.parents("div.cell:first");
#                 if (cell_892092261.length == 0) {
#                     cell_892092261 = link_892092261.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_892092261 = cell_892092261.children("div.input");
#                 if (input_892092261.length == 0) {
#                     input_892092261 = cell_892092261.prev("div.nbinput");
#                 }
#                 input_892092261.hide();
#
#                 toggle_input_892092261 = function() {
#                     if (input_892092261.is(':hidden')) {
#                         input_892092261.slideDown();
#                         link_892092261[0].innerHTML = "Hide Input";
#                     } else {
#                         input_892092261.slideUp();
#                         link_892092261[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1576854071" href="javascript:toggle_input_1576854071()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1576854071;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1576854071 = document.getElementById("1576854071");
#                 var cell = link_1576854071;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1576854071;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1576854071 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1576854071 = cell.previousElementSibling;
#                 }
#                 input_1576854071.style.display = "none"; // hide
#
#                 toggle_input_1576854071 = function() {
#                     if (input_1576854071.style.display == "none") {
#                         input_1576854071.style.display = ""; // show
#                         link_1576854071.innerHTML = "Hide Input";
#                     } else {
#                         input_1576854071.style.display = "none"; // hide
#                         link_1576854071.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1576854071 = $("a[id='1576854071']");
#                 var cell_1576854071 = link_1576854071.parents("div.cell:first");
#                 if (cell_1576854071.length == 0) {
#                     cell_1576854071 = link_1576854071.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1576854071 = cell_1576854071.children("div.input");
#                 if (input_1576854071.length == 0) {
#                     input_1576854071 = cell_1576854071.prev("div.nbinput");
#                 }
#                 input_1576854071.hide();
#
#                 toggle_input_1576854071 = function() {
#                     if (input_1576854071.is(':hidden')) {
#                         input_1576854071.slideDown();
#                         link_1576854071[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1576854071.slideUp();
#                         link_1576854071[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1819621014" href="javascript:toggle_input_1819621014()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1819621014;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1819621014 = document.getElementById("1819621014");
#                 var cell = link_1819621014;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1819621014;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1819621014 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1819621014 = cell.previousElementSibling;
#                 }
#                 input_1819621014.style.display = "none"; // hide
#
#                 toggle_input_1819621014 = function() {
#                     if (input_1819621014.style.display == "none") {
#                         input_1819621014.style.display = ""; // show
#                         link_1819621014.innerHTML = "Hide Input";
#                     } else {
#                         input_1819621014.style.display = "none"; // hide
#                         link_1819621014.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1819621014 = $("a[id='1819621014']");
#                 var cell_1819621014 = link_1819621014.parents("div.cell:first");
#                 if (cell_1819621014.length == 0) {
#                     cell_1819621014 = link_1819621014.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1819621014 = cell_1819621014.children("div.input");
#                 if (input_1819621014.length == 0) {
#                     input_1819621014 = cell_1819621014.prev("div.nbinput");
#                 }
#                 input_1819621014.hide();
#
#                 toggle_input_1819621014 = function() {
#                     if (input_1819621014.is(':hidden')) {
#                         input_1819621014.slideDown();
#                         link_1819621014[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1819621014.slideUp();
#                         link_1819621014[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="635202357" href="javascript:toggle_input_635202357()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_635202357;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_635202357 = document.getElementById("635202357");
#                 var cell = link_635202357;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_635202357;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_635202357 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_635202357 = cell.previousElementSibling;
#                 }
#                 input_635202357.style.display = "none"; // hide
#
#                 toggle_input_635202357 = function() {
#                     if (input_635202357.style.display == "none") {
#                         input_635202357.style.display = ""; // show
#                         link_635202357.innerHTML = "Hide Input";
#                     } else {
#                         input_635202357.style.display = "none"; // hide
#                         link_635202357.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_635202357 = $("a[id='635202357']");
#                 var cell_635202357 = link_635202357.parents("div.cell:first");
#                 if (cell_635202357.length == 0) {
#                     cell_635202357 = link_635202357.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_635202357 = cell_635202357.children("div.input");
#                 if (input_635202357.length == 0) {
#                     input_635202357 = cell_635202357.prev("div.nbinput");
#                 }
#                 input_635202357.hide();
#
#                 toggle_input_635202357 = function() {
#                     if (input_635202357.is(':hidden')) {
#                         input_635202357.slideDown();
#                         link_635202357[0].innerHTML = "Hide Input";
#                     } else {
#                         input_635202357.slideUp();
#                         link_635202357[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="265097523" href="javascript:toggle_input_265097523()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_265097523;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_265097523 = document.getElementById("265097523");
#                 var cell = link_265097523;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_265097523;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_265097523 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_265097523 = cell.previousElementSibling;
#                 }
#                 input_265097523.style.display = "none"; // hide
#
#                 toggle_input_265097523 = function() {
#                     if (input_265097523.style.display == "none") {
#                         input_265097523.style.display = ""; // show
#                         link_265097523.innerHTML = "Hide Input";
#                     } else {
#                         input_265097523.style.display = "none"; // hide
#                         link_265097523.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_265097523 = $("a[id='265097523']");
#                 var cell_265097523 = link_265097523.parents("div.cell:first");
#                 if (cell_265097523.length == 0) {
#                     cell_265097523 = link_265097523.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_265097523 = cell_265097523.children("div.input");
#                 if (input_265097523.length == 0) {
#                     input_265097523 = cell_265097523.prev("div.nbinput");
#                 }
#                 input_265097523.hide();
#
#                 toggle_input_265097523 = function() {
#                     if (input_265097523.is(':hidden')) {
#                         input_265097523.slideDown();
#                         link_265097523[0].innerHTML = "Hide Input";
#                     } else {
#                         input_265097523.slideUp();
#                         link_265097523[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="381808327" href="javascript:toggle_input_381808327()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_381808327;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_381808327 = document.getElementById("381808327");
#                 var cell = link_381808327;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_381808327;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_381808327 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_381808327 = cell.previousElementSibling;
#                 }
#                 input_381808327.style.display = "none"; // hide
#
#                 toggle_input_381808327 = function() {
#                     if (input_381808327.style.display == "none") {
#                         input_381808327.style.display = ""; // show
#                         link_381808327.innerHTML = "Hide Input";
#                     } else {
#                         input_381808327.style.display = "none"; // hide
#                         link_381808327.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_381808327 = $("a[id='381808327']");
#                 var cell_381808327 = link_381808327.parents("div.cell:first");
#                 if (cell_381808327.length == 0) {
#                     cell_381808327 = link_381808327.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_381808327 = cell_381808327.children("div.input");
#                 if (input_381808327.length == 0) {
#                     input_381808327 = cell_381808327.prev("div.nbinput");
#                 }
#                 input_381808327.hide();
#
#                 toggle_input_381808327 = function() {
#                     if (input_381808327.is(':hidden')) {
#                         input_381808327.slideDown();
#                         link_381808327[0].innerHTML = "Hide Input";
#                     } else {
#                         input_381808327.slideUp();
#                         link_381808327[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="463472731" href="javascript:toggle_input_463472731()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_463472731;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_463472731 = document.getElementById("463472731");
#                 var cell = link_463472731;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_463472731;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_463472731 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_463472731 = cell.previousElementSibling;
#                 }
#                 input_463472731.style.display = "none"; // hide
#
#                 toggle_input_463472731 = function() {
#                     if (input_463472731.style.display == "none") {
#                         input_463472731.style.display = ""; // show
#                         link_463472731.innerHTML = "Hide Input";
#                     } else {
#                         input_463472731.style.display = "none"; // hide
#                         link_463472731.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_463472731 = $("a[id='463472731']");
#                 var cell_463472731 = link_463472731.parents("div.cell:first");
#                 if (cell_463472731.length == 0) {
#                     cell_463472731 = link_463472731.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_463472731 = cell_463472731.children("div.input");
#                 if (input_463472731.length == 0) {
#                     input_463472731 = cell_463472731.prev("div.nbinput");
#                 }
#                 input_463472731.hide();
#
#                 toggle_input_463472731 = function() {
#                     if (input_463472731.is(':hidden')) {
#                         input_463472731.slideDown();
#                         link_463472731[0].innerHTML = "Hide Input";
#                     } else {
#                         input_463472731.slideUp();
#                         link_463472731[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="1110245353" href="javascript:toggle_input_1110245353()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1110245353;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1110245353 = document.getElementById("1110245353");
#                 var cell = link_1110245353;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1110245353;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1110245353 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1110245353 = cell.previousElementSibling;
#                 }
#                 input_1110245353.style.display = "none"; // hide
#
#                 toggle_input_1110245353 = function() {
#                     if (input_1110245353.style.display == "none") {
#                         input_1110245353.style.display = ""; // show
#                         link_1110245353.innerHTML = "Hide Input";
#                     } else {
#                         input_1110245353.style.display = "none"; // hide
#                         link_1110245353.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1110245353 = $("a[id='1110245353']");
#                 var cell_1110245353 = link_1110245353.parents("div.cell:first");
#                 if (cell_1110245353.length == 0) {
#                     cell_1110245353 = link_1110245353.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1110245353 = cell_1110245353.children("div.input");
#                 if (input_1110245353.length == 0) {
#                     input_1110245353 = cell_1110245353.prev("div.nbinput");
#                 }
#                 input_1110245353.hide();
#
#                 toggle_input_1110245353 = function() {
#                     if (input_1110245353.is(':hidden')) {
#                         input_1110245353.slideDown();
#                         link_1110245353[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1110245353.slideUp();
#                         link_1110245353[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
